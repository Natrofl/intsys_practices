# %% [markdown]
# ### 1、please import pandas

# %%
import pandas as pd

# %% [markdown]
# ### 2、please read the Breast_cancer_data_for_ML.csv file and saved as DataFrame and name it as 'data'.

# %%
df = pd.read_csv('E:\_Документы\Учеба\Интеллектуальные системы\HCIA-AI\HCIA-AI\The second day\Experiments\Breast_cancer_data_for_ML.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### 3、please drop the 'Unnamed: 32' column

# %%
df = df.drop(['Unnamed: 32'], axis='columns')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### 4、please to use 1,0 instead of 'M' and 'B'

# %%
df.loc[df['diagnosis'] == 'M', 'diagnosis'] = 1
df.loc[df['diagnosis'] == 'B', 'diagnosis'] = 0
df = df
display(df)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         1        17.99         10.38          122.80     1001.0
# 1      842517         1        20.57         17.77          132.90     1326.0
# 2    84300903         1        19.69         21.25          130.00     1203.0
# 3    84348301         1        11.42         20.38           77.58      386.1
# 4    84358402         1        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         1        21.56         22.39          142.00     1479.0
# 565    926682         1        20.13         28.25          131.20     1261.0
# 566    926954         1        16.60         28.08          108.30      858.1
# 567    927241         1        20.60         29.33          140.10     1265.0
# 568     92751         0         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### 5、please split the data into training data and test data

# %%
#один из вариантов разделить датасет на тренировочный и тестовый наборы
train=df.sample(frac=0.7,random_state=200)
test=df.drop(train.index)
display(train)
display(test)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 225  88143502         0        14.34         13.47           92.51      641.2
# 385     90291         1        14.60         23.29           93.97      664.7
# 338    897880         0        10.05         17.53           64.41      310.8
# 458   9112594         0        13.00         25.13           82.61      520.2
# 495    914333         0        14.87         20.21           96.12      680.9
# ..        ...       ...          ...           ...             ...        ...
# 421    906564         0        14.69         13.98           98.22      656.1
# 144    869254         0        10.75         14.97           68.26      355.3
# 195    875878         0        12.91         16.33           82.53      516.4
# 403      9047         0        12.94         16.17           83.18      507.6
# 387    902976         0        13.88         16.16           88.37      596.6
#
# ...

# %% [markdown]
# ### 6、please do data preprocesing

# %%
#def normalize(dataset):
#    dataNorm=((dataset-dataset.min())/(dataset.max()-dataset.min()))*20
#    dataNorm["diagnosis"]=dataset["diagnosis"]
#    dataNorm["id"]=dataset["id"]
#    return dataNorm

#df1 = normalize(df)
#train = normalize(train)
#test = normalize(test)
#display(df1)

X = df.drop(['diagnosis'], axis=1)
(X+0.001).hist(figsize=(20, 15), color = 'c');

# %% [markdown]
# ### 7、please use SVM to do classification

# %%
import numpy as np
X = df1.drop(['diagnosis'], axis=1)
X_log = np.log(X+0.001)
from sklearn.model_selection import train_test_split
y = df1['diagnosis']
y=y.astype('int')
X_train, X_test, y_train, y_test = train_test_split(X_log, y, test_size=0.3, random_state=17)

# %%
from sklearn.svm import SVC
name_model=SVC()

# %%
from sklearn.svm import SVC
SVM_model = SVC()
SVM_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
svm_pred = SVM_model.predict(X_test)
print ("Оценка точности: ",accuracy_score(y_test, svm_pred) )
print ("Предсказано правильно: ",recall_score(y_test, svm_pred))
print ("Оценка точности (сколько опухолей, которые были предсказаны как «злокачественные», на самом деле оказались «злокачественными»): ",precision_score(y_test, svm_pred))
# Out:
# Оценка точности:  0.9590643274853801
# Предсказано правильно:  0.9180327868852459
# Оценка точности (сколько опухолей, которые были предсказаны как «злокачественные», на самом деле оказались «злокачественными»):  0.9655172413793104
